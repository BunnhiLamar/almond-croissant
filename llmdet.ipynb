# %%
import torch
from transformers import AutoModelForZeroShotObjectDetection, AutoProcessor
from transformers.image_utils import load_image
import torch
import cv2
import numpy as np
import os
import random
from transformers import AutoModelForZeroShotObjectDetection, AutoProcessor
from PIL import Image
# Deep SORT imports
from deep_sort.deep_sort.tracker import Tracker as DeepSortTracker
from deep_sort.tools import generate_detections as gdet
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.detection import Detection

# %%
# Prepare processor and model
model_id = "iSEE-Laboratory/llmdet_tiny"
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)

# Prepare inputs
image_url = "/home/nhinguyen/Desktop/OmniLRS/OmniLRS/scripts/nhi/rover_data_20250804_114916/photo_0038.jpg"
image = load_image(image_url)
text_labels = [["rover"]]
inputs = processor(images=image, text=text_labels, return_tensors="pt").to(device)

# Run inference
with torch.no_grad():
    outputs = model(**inputs)

# Postprocess outputs
results = processor.post_process_grounded_object_detection(
    outputs,
    threshold=0.4,
    target_sizes=[(image.height, image.width)]
)

# Retrieve the first image result
result = results[0]
for box, score, labels in zip(result["boxes"], result["scores"], result["labels"]):
    box = [round(x, 2) for x in box.tolist()]
    print(f"Detected {labels} with confidence {round(score.item(), 3)} at location {box}")
# Out:
# Detected rover with confidence 0.733 at location [249.08, 542.25, 421.49, 648.52]
# Detected rover with confidence 0.732 at location [1042.32, 500.53, 1172.6, 577.09]

# %%
# Load model
model_id = "iSEE-Laboratory/llmdet_tiny"
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)

# Video paths and settings
input_video = "/home/nhinguyen/Downloads/lunar_videos/1.mp4"
output_video = "/home/nhinguyen/Downloads/lunar_videos/1_detect.mp4"
text_labels = [["rover", "robot", "occluded rover", "moving rover"]]
threshold = 0.4

# Process video
cap = cv2.VideoCapture(input_video)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    # Convert and detect
    pil_img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    inputs = processor(images=pil_img, text=text_labels, return_tensors="pt").to(device)
    
    with torch.no_grad():
        outputs = model(**inputs)
    
    results = processor.post_process_grounded_object_detection(
        outputs, threshold=threshold, target_sizes=[(pil_img.height, pil_img.width)]
    )[0]
    
    # Draw boxes
    for box, score, label in zip(results["boxes"], results["scores"], results["labels"]):
        x1, y1, x2, y2 = [int(x) for x in box.tolist()]
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f"{label}: {score:.3f}", (x1, y1-10), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    out.write(frame)

cap.release()
out.release()

# %% [markdown]
# ### __DeepSORT__

# %%
class Track:
    """
    A simple container to hold track_id and bbox data.
    """
    def __init__(self, track_id, bbox):
        self.track_id = track_id
        self.bbox = bbox


class DeepSortWrapper:
    """
    Wrapper class around the Deep SORT functionality.
    """
    def __init__(self, model_filename='model_data/mars-small128.pb', max_cosine_distance=0.4, nn_budget=None):
        metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
        self.tracker = DeepSortTracker(metric)
        self.encoder = gdet.create_box_encoder(model_filename, batch_size=1)
        self.tracks = []

    def update(self, frame, detections):
        """
        Args:
            frame (numpy.ndarray): Current video frame (BGR).
            detections (list): List of detections in [x1, y1, x2, y2, score] format.
        """

        # Step 1: If no detections, just run tracker predict
        if len(detections) == 0:
            self.tracker.predict()
            self.tracker.update([])
            self._update_tracks()
            return

        # Step 2: Convert [x1, y1, x2, y2] to [x, y, w, h]
        bboxes = np.array([d[:4] for d in detections])
        scores = [d[4] for d in detections]

        bboxes[:, 2:] = bboxes[:, 2:] - bboxes[:, :2]  # width, height

        # Step 3: Generate features for each bbox
        features = self.encoder(frame, bboxes)

        # Step 4: Wrap Deep SORT detections
        dets = []
        for bbox_id, bbox in enumerate(bboxes):
            dets.append(Detection(bbox, scores[bbox_id], features[bbox_id]))

        # Step 5: Run the tracker
        self.tracker.predict()
        self.tracker.update(dets)
        self._update_tracks()

    def _update_tracks(self):
        """
        Refresh self.tracks with updated tracks from the deep_sort tracker
        """
        active_tracks = []
        for track in self.tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()  # returns [x1, y1, x2, y2]
            track_id = track.track_id
            active_tracks.append(Track(track_id, bbox))

        self.tracks = active_tracks

# %% [markdown]
# ### __LLMDet + DeepSort__

# %%
# Load model
model_id = "iSEE-Laboratory/llmdet_tiny"
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)

# Video paths and settings
input_video = "/home/nhinguyen/Downloads/lunar_videos/1.mp4"
output_video = "/home/nhinguyen/Downloads/lunar_videos/1_detect_tracking.mp4"
text_labels = [["rover"]]
threshold = 0.4

# output_dir = "/results/"

# Process video
cap = cv2.VideoCapture(input_video)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# %%
from natsort import natsorted
import glob
image_dir = f"C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504/"
output_dir=os.path.join(f"C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/", image_dir.split('/')[-2]+'_2/')
pattern = "photo"
images = natsorted(glob.glob(f"{image_dir}{pattern}*.jpg"))
# images
os.makedirs(output_dir,exist_ok=True)
print(output_dir)
# Out:
# C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_112504_2/

# %%
train_data = glob.glob(f"C:/Users/ongng/OneDrive/Desktop/rover_data*")
print(train_data[:3])
# Out:
# ['C:/Users/ongng/OneDrive/Desktop\\rover_data_20250804_112504', 'C:/Users/ongng/OneDrive/Desktop\\rover_data_20250804_114916', 'C:/Users/ongng/OneDrive/Desktop\\rover_data_20250804_115254']

# %%
deepsort = DeepSortWrapper(
    model_filename="C:\\Users\\ongng\\Downloads\\Sample_Detection_Tracking_Yolov8_DeepSORT_Robotics-main\\Sample_Detection_Tracking_Yolov8_DeepSORT_Robotics-main\\deep_sort\\deep_sort\mars-small128.pb",
    max_cosine_distance=0.4,
    nn_budget=None
)
for image_dir in train_data:
    
    # if image_dir == "C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504/":
    #     continue
    print("Loading", image_dir)
    output_dir=f"C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/"+ image_dir.replace('\\','/').split('/')[-1]
    print("Output directory:", output_dir)
    pattern = "photo"
    images = natsorted(glob.glob(f"{image_dir}/{pattern}*.jpg"))
    # print(f"{image_dir}{pattern}*.jpg")
    os.makedirs(output_dir,exist_ok=True)
    
    #===============
    colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for _ in range(100)]
    for i in range(len(images)):
        img_ = cv2.imread(images[i])
        img = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
        pil_img = Image.fromarray(img)
        inputs = processor(images=pil_img, text=text_labels, return_tensors="pt").to(device)
        # inputs = processor(images=pil_img, text=text_labels, return_tensors="pt").to(device)
        
        with torch.no_grad():
            outputs = model(**inputs)
        
        results = processor.post_process_grounded_object_detection(
            outputs, threshold=threshold, target_sizes=[(pil_img.height, pil_img.width)]
        )[0]

        bboxes = [b.cpu().detach().numpy() for b in results['boxes']]
        scores = [s.cpu().detach().numpy() for s in results['scores']]
        detections = [list(bboxes[i]) + [scores[i]] for i in range(len(scores))]


        #DEEP SORT------------------------

        deepsort.update(img, detections)
        # print
        for track in deepsort.tracks:
            # print(track)
            x1, y1, x2, y2 = track.bbox
            track_id = track.track_id
            
            color = colors[track_id % len(colors)]
            cv2.rectangle(img_, (int(x1), int(y1)), (int(x2), int(y2)), color, 1)
            cv2.putText(img_, f"ID: {track_id}", (int(x1), int(y1) - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

        out_img_dir = output_dir+"/"+f"{i:04}.jpg"
        cv2.imwrite(out_img_dir, img_)
        if i%30 == 0:
            print(f'Detected {i}/{len(images)} images')
# Out:
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_112504
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_112504
# Detected 0/1177 images
# Detected 30/1177 images
# Detected 60/1177 images
# Detected 90/1177 images
# Detected 120/1177 images
# Detected 150/1177 images
# Detected 180/1177 images
# Detected 210/1177 images
# Detected 240/1177 images
# Detected 270/1177 images
# Detected 300/1177 images
# Detected 330/1177 images
# Detected 360/1177 images
# Detected 390/1177 images
# Detected 420/1177 images
# Detected 450/1177 images
# Detected 480/1177 images
# Detected 510/1177 images
# Detected 540/1177 images
# Detected 570/1177 images
# Detected 600/1177 images
# Detected 630/1177 images
# Detected 660/1177 images
# Detected 690/1177 images
# Detected 720/1177 images
# Detected 750/1177 images
# Detected 780/1177 images
# Detected 810/1177 images
# Detected 840/1177 images
# Detected 870/1177 images
# Detected 900/1177 images
# Detected 930/1177 images
# Detected 960/1177 images
# Detected 990/1177 images
# Detected 1020/1177 images
# Detected 1050/1177 images
# Detected 1080/1177 images
# Detected 1110/1177 images
# Detected 1140/1177 images
# Detected 1170/1177 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_114916
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_114916
# Detected 0/1134 images
# Detected 30/1134 images
# Detected 60/1134 images
# Detected 90/1134 images
# Detected 120/1134 images
# Detected 150/1134 images
# Detected 180/1134 images
# Detected 210/1134 images
# Detected 240/1134 images
# Detected 270/1134 images
# Detected 300/1134 images
# Detected 330/1134 images
# Detected 360/1134 images
# Detected 390/1134 images
# Detected 420/1134 images
# Detected 450/1134 images
# Detected 480/1134 images
# Detected 510/1134 images
# Detected 540/1134 images
# Detected 570/1134 images
# Detected 600/1134 images
# Detected 630/1134 images
# Detected 660/1134 images
# Detected 690/1134 images
# Detected 720/1134 images
# Detected 750/1134 images
# Detected 780/1134 images
# Detected 810/1134 images
# Detected 840/1134 images
# Detected 870/1134 images
# Detected 900/1134 images
# Detected 930/1134 images
# Detected 960/1134 images
# Detected 990/1134 images
# Detected 1020/1134 images
# Detected 1050/1134 images
# Detected 1080/1134 images
# Detected 1110/1134 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_115254
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_115254
# Detected 0/990 images
# Detected 30/990 images
# Detected 60/990 images
# Detected 90/990 images
# Detected 120/990 images
# Detected 150/990 images
# Detected 180/990 images
# Detected 210/990 images
# Detected 240/990 images
# Detected 270/990 images
# Detected 300/990 images
# Detected 330/990 images
# Detected 360/990 images
# Detected 390/990 images
# Detected 420/990 images
# Detected 450/990 images
# Detected 480/990 images
# Detected 510/990 images
# Detected 540/990 images
# Detected 570/990 images
# Detected 600/990 images
# Detected 630/990 images
# Detected 660/990 images
# Detected 690/990 images
# Detected 720/990 images
# Detected 750/990 images
# Detected 780/990 images
# Detected 810/990 images
# Detected 840/990 images
# Detected 870/990 images
# Detected 900/990 images
# Detected 930/990 images
# Detected 960/990 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_115631
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_115631
# Detected 0/955 images
# Detected 30/955 images
# Detected 60/955 images
# Detected 90/955 images
# Detected 120/955 images
# Detected 150/955 images
# Detected 180/955 images
# Detected 210/955 images
# Detected 240/955 images
# Detected 270/955 images
# Detected 300/955 images
# Detected 330/955 images
# Detected 360/955 images
# Detected 390/955 images
# Detected 420/955 images
# Detected 450/955 images
# Detected 480/955 images
# Detected 510/955 images
# Detected 540/955 images
# Detected 570/955 images
# Detected 600/955 images
# Detected 630/955 images
# Detected 660/955 images
# Detected 690/955 images
# Detected 720/955 images
# Detected 750/955 images
# Detected 780/955 images
# Detected 810/955 images
# Detected 840/955 images
# Detected 870/955 images
# Detected 900/955 images
# Detected 930/955 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_123128
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_123128
# Detected 0/110 images
# Detected 30/110 images
# Detected 60/110 images
# Detected 90/110 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_123231
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_123231
# Detected 0/1634 images
# Detected 30/1634 images
# Detected 60/1634 images
# Detected 90/1634 images
# Detected 120/1634 images
# Detected 150/1634 images
# Detected 180/1634 images
# Detected 210/1634 images
# Detected 240/1634 images
# Detected 270/1634 images
# Detected 300/1634 images
# Detected 330/1634 images
# Detected 360/1634 images
# Detected 390/1634 images
# Detected 420/1634 images
# Detected 450/1634 images
# Detected 480/1634 images
# Detected 510/1634 images
# Detected 540/1634 images
# Detected 570/1634 images
# Detected 600/1634 images
# Detected 630/1634 images
# Detected 660/1634 images
# Detected 690/1634 images
# Detected 720/1634 images
# Detected 750/1634 images
# Detected 780/1634 images
# Detected 810/1634 images
# Detected 840/1634 images
# Detected 870/1634 images
# Detected 900/1634 images
# Detected 930/1634 images
# Detected 960/1634 images
# Detected 990/1634 images
# Detected 1020/1634 images
# Detected 1050/1634 images
# Detected 1080/1634 images
# Detected 1110/1634 images
# Detected 1140/1634 images
# Detected 1170/1634 images
# Detected 1200/1634 images
# Detected 1230/1634 images
# Detected 1260/1634 images
# Detected 1290/1634 images
# Detected 1320/1634 images
# Detected 1350/1634 images
# Detected 1380/1634 images
# Detected 1410/1634 images
# Detected 1440/1634 images
# Detected 1470/1634 images
# Detected 1500/1634 images
# Detected 1530/1634 images
# Detected 1560/1634 images
# Detected 1590/1634 images
# Detected 1620/1634 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_123548
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_123548
# Detected 0/1584 images
# Detected 30/1584 images
# Detected 60/1584 images
# Detected 90/1584 images
# Detected 120/1584 images
# Detected 150/1584 images
# Detected 180/1584 images
# Detected 210/1584 images
# Detected 240/1584 images
# Detected 270/1584 images
# Detected 300/1584 images
# Detected 330/1584 images
# Detected 360/1584 images
# Detected 390/1584 images
# Detected 420/1584 images
# Detected 450/1584 images
# Detected 480/1584 images
# Detected 510/1584 images
# Detected 540/1584 images
# Detected 570/1584 images
# Detected 600/1584 images
# Detected 630/1584 images
# Detected 660/1584 images
# Detected 690/1584 images
# Detected 720/1584 images
# Detected 750/1584 images
# Detected 780/1584 images
# Detected 810/1584 images
# Detected 840/1584 images
# Detected 870/1584 images
# Detected 900/1584 images
# Detected 930/1584 images
# Detected 960/1584 images
# Detected 990/1584 images
# Detected 1020/1584 images
# Detected 1050/1584 images
# Detected 1080/1584 images
# Detected 1110/1584 images
# Detected 1140/1584 images
# Detected 1170/1584 images
# Detected 1200/1584 images
# Detected 1230/1584 images
# Detected 1260/1584 images
# Detected 1290/1584 images
# Detected 1320/1584 images
# Detected 1350/1584 images
# Detected 1380/1584 images
# Detected 1410/1584 images
# Detected 1440/1584 images
# Detected 1470/1584 images
# Detected 1500/1584 images
# Detected 1530/1584 images
# Detected 1560/1584 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_123808
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_123808
# Detected 0/1260 images
# Detected 30/1260 images
# Detected 60/1260 images
# Detected 90/1260 images
# Detected 120/1260 images
# Detected 150/1260 images
# Detected 180/1260 images
# Detected 210/1260 images
# Detected 240/1260 images
# Detected 270/1260 images
# Detected 300/1260 images
# Detected 330/1260 images
# Detected 360/1260 images
# Detected 390/1260 images
# Detected 420/1260 images
# Detected 450/1260 images
# Detected 480/1260 images
# Detected 510/1260 images
# Detected 540/1260 images
# Detected 570/1260 images
# Detected 600/1260 images
# Detected 630/1260 images
# Detected 660/1260 images
# Detected 690/1260 images
# Detected 720/1260 images
# Detected 750/1260 images
# Detected 780/1260 images
# Detected 810/1260 images
# Detected 840/1260 images
# Detected 870/1260 images
# Detected 900/1260 images
# Detected 930/1260 images
# Detected 960/1260 images
# Detected 990/1260 images
# Detected 1020/1260 images
# Detected 1050/1260 images
# Detected 1080/1260 images
# Detected 1110/1260 images
# Detected 1140/1260 images
# Detected 1170/1260 images
# Detected 1200/1260 images
# Detected 1230/1260 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_124042
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_124042
# Detected 0/1299 images
# Detected 30/1299 images
# Detected 60/1299 images
# Detected 90/1299 images
# Detected 120/1299 images
# Detected 150/1299 images
# Detected 180/1299 images
# Detected 210/1299 images
# Detected 240/1299 images
# Detected 270/1299 images
# Detected 300/1299 images
# Detected 330/1299 images
# Detected 360/1299 images
# Detected 390/1299 images
# Detected 420/1299 images
# Detected 450/1299 images
# Detected 480/1299 images
# Detected 510/1299 images
# Detected 540/1299 images
# Detected 570/1299 images
# Detected 600/1299 images
# Detected 630/1299 images
# Detected 660/1299 images
# Detected 690/1299 images
# Detected 720/1299 images
# Detected 750/1299 images
# Detected 780/1299 images
# Detected 810/1299 images
# Detected 840/1299 images
# Detected 870/1299 images
# Detected 900/1299 images
# Detected 930/1299 images
# Detected 960/1299 images
# Detected 990/1299 images
# Detected 1020/1299 images
# Detected 1050/1299 images
# Detected 1080/1299 images
# Detected 1110/1299 images
# Detected 1140/1299 images
# Detected 1170/1299 images
# Detected 1200/1299 images
# Detected 1230/1299 images
# Detected 1260/1299 images
# Detected 1290/1299 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_124232
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_124232
# Detected 0/1224 images
# Detected 30/1224 images
# Detected 60/1224 images
# Detected 90/1224 images
# Detected 120/1224 images
# Detected 150/1224 images
# Detected 180/1224 images
# Detected 210/1224 images
# Detected 240/1224 images
# Detected 270/1224 images
# Detected 300/1224 images
# Detected 330/1224 images
# Detected 360/1224 images
# Detected 390/1224 images
# Detected 420/1224 images
# Detected 450/1224 images
# Detected 480/1224 images
# Detected 510/1224 images
# Detected 540/1224 images
# Detected 570/1224 images
# Detected 600/1224 images
# Detected 630/1224 images
# Detected 660/1224 images
# Detected 690/1224 images
# Detected 720/1224 images
# Detected 750/1224 images
# Detected 780/1224 images
# Detected 810/1224 images
# Detected 840/1224 images
# Detected 870/1224 images
# Detected 900/1224 images
# Detected 930/1224 images
# Detected 960/1224 images
# Detected 990/1224 images
# Detected 1020/1224 images
# Detected 1050/1224 images
# Detected 1080/1224 images
# Detected 1110/1224 images
# Detected 1140/1224 images
# Detected 1170/1224 images
# Detected 1200/1224 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_124646
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_124646
# Detected 0/1237 images
# Detected 30/1237 images
# Detected 60/1237 images
# Detected 90/1237 images
# Detected 120/1237 images
# Detected 150/1237 images
# Detected 180/1237 images
# Detected 210/1237 images
# Detected 240/1237 images
# Detected 270/1237 images
# Detected 300/1237 images
# Detected 330/1237 images
# Detected 360/1237 images
# Detected 390/1237 images
# Detected 420/1237 images
# Detected 450/1237 images
# Detected 480/1237 images
# Detected 510/1237 images
# Detected 540/1237 images
# Detected 570/1237 images
# Detected 600/1237 images
# Detected 630/1237 images
# Detected 660/1237 images
# Detected 690/1237 images
# Detected 720/1237 images
# Detected 750/1237 images
# Detected 780/1237 images
# Detected 810/1237 images
# Detected 840/1237 images
# Detected 870/1237 images
# Detected 900/1237 images
# Detected 930/1237 images
# Detected 960/1237 images
# Detected 990/1237 images
# Detected 1020/1237 images
# Detected 1050/1237 images
# Detected 1080/1237 images
# Detected 1110/1237 images
# Detected 1140/1237 images
# Detected 1170/1237 images
# Detected 1200/1237 images
# Detected 1230/1237 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_124846
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_124846
# Detected 0/1060 images
# Detected 30/1060 images
# Detected 60/1060 images
# Detected 90/1060 images
# Detected 120/1060 images
# Detected 150/1060 images
# Detected 180/1060 images
# Detected 210/1060 images
# Detected 240/1060 images
# Detected 270/1060 images
# Detected 300/1060 images
# Detected 330/1060 images
# Detected 360/1060 images
# Detected 390/1060 images
# Detected 420/1060 images
# Detected 450/1060 images
# Detected 480/1060 images
# Detected 510/1060 images
# Detected 540/1060 images
# Detected 570/1060 images
# Detected 600/1060 images
# Detected 630/1060 images
# Detected 660/1060 images
# Detected 690/1060 images
# Detected 720/1060 images
# Detected 750/1060 images
# Detected 780/1060 images
# Detected 810/1060 images
# Detected 840/1060 images
# Detected 870/1060 images
# Detected 900/1060 images
# Detected 930/1060 images
# Detected 960/1060 images
# Detected 990/1060 images
# Detected 1020/1060 images
# Detected 1050/1060 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_125527
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_125527
# Detected 0/897 images
# Detected 30/897 images
# Detected 60/897 images
# Detected 90/897 images
# Detected 120/897 images
# Detected 150/897 images
# Detected 180/897 images
# Detected 210/897 images
# Detected 240/897 images
# Detected 270/897 images
# Detected 300/897 images
# Detected 330/897 images
# Detected 360/897 images
# Detected 390/897 images
# Detected 420/897 images
# Detected 450/897 images
# Detected 480/897 images
# Detected 510/897 images
# Detected 540/897 images
# Detected 570/897 images
# Detected 600/897 images
# Detected 630/897 images
# Detected 660/897 images
# Detected 690/897 images
# Detected 720/897 images
# Detected 750/897 images
# Detected 780/897 images
# Detected 810/897 images
# Detected 840/897 images
# Detected 870/897 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_125707
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_125707
# Detected 0/831 images
# Detected 30/831 images
# Detected 60/831 images
# Detected 90/831 images
# Detected 120/831 images
# Detected 150/831 images
# Detected 180/831 images
# Detected 210/831 images
# Detected 240/831 images
# Detected 270/831 images
# Detected 300/831 images
# Detected 330/831 images
# Detected 360/831 images
# Detected 390/831 images
# Detected 420/831 images
# Detected 450/831 images
# Detected 480/831 images
# Detected 510/831 images
# Detected 540/831 images
# Detected 570/831 images
# Detected 600/831 images
# Detected 630/831 images
# Detected 660/831 images
# Detected 690/831 images
# Detected 720/831 images
# Detected 750/831 images
# Detected 780/831 images
# Detected 810/831 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_125952
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_125952
# Detected 0/1186 images
# Detected 30/1186 images
# Detected 60/1186 images
# Detected 90/1186 images
# Detected 120/1186 images
# Detected 150/1186 images
# Detected 180/1186 images
# Detected 210/1186 images
# Detected 240/1186 images
# Detected 270/1186 images
# Detected 300/1186 images
# Detected 330/1186 images
# Detected 360/1186 images
# Detected 390/1186 images
# Detected 420/1186 images
# Detected 450/1186 images
# Detected 480/1186 images
# Detected 510/1186 images
# Detected 540/1186 images
# Detected 570/1186 images
# Detected 600/1186 images
# Detected 630/1186 images
# Detected 660/1186 images
# Detected 690/1186 images
# Detected 720/1186 images
# Detected 750/1186 images
# Detected 780/1186 images
# Detected 810/1186 images
# Detected 840/1186 images
# Detected 870/1186 images
# Detected 900/1186 images
# Detected 930/1186 images
# Detected 960/1186 images
# Detected 990/1186 images
# Detected 1020/1186 images
# Detected 1050/1186 images
# Detected 1080/1186 images
# Detected 1110/1186 images
# Detected 1140/1186 images
# Detected 1170/1186 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_130123
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_130123
# Detected 0/1051 images
# Detected 30/1051 images
# Detected 60/1051 images
# Detected 90/1051 images
# Detected 120/1051 images
# Detected 150/1051 images
# Detected 180/1051 images
# Detected 210/1051 images
# Detected 240/1051 images
# Detected 270/1051 images
# Detected 300/1051 images
# Detected 330/1051 images
# Detected 360/1051 images
# Detected 390/1051 images
# Detected 420/1051 images
# Detected 450/1051 images
# Detected 480/1051 images
# Detected 510/1051 images
# Detected 540/1051 images
# Detected 570/1051 images
# Detected 600/1051 images
# Detected 630/1051 images
# Detected 660/1051 images
# Detected 690/1051 images
# Detected 720/1051 images
# Detected 750/1051 images
# Detected 780/1051 images
# Detected 810/1051 images
# Detected 840/1051 images
# Detected 870/1051 images
# Detected 900/1051 images
# Detected 930/1051 images
# Detected 960/1051 images
# Detected 990/1051 images
# Detected 1020/1051 images
# Detected 1050/1051 images
# Loading C:/Users/ongng/OneDrive/Desktop\rover_data_20250804_130421
# Output directory: C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_130421
# Detected 0/783 images
# Detected 30/783 images
# Detected 60/783 images
# Detected 90/783 images
# Detected 120/783 images
# Detected 150/783 images
# Detected 180/783 images
# Detected 210/783 images
# Detected 240/783 images
# Detected 270/783 images
# Detected 300/783 images
# Detected 330/783 images
# Detected 360/783 images
# Detected 390/783 images
# Detected 420/783 images
# Detected 450/783 images
# Detected 480/783 images
# Detected 510/783 images
# Detected 540/783 images
# Detected 570/783 images
# Detected 600/783 images
# Detected 630/783 images
# Detected 660/783 images
# Detected 690/783 images
# Detected 720/783 images
# Detected 750/783 images
# Detected 780/783 images

# %%
# deepsort = DeepSortWrapper(
#     model_filename="C:\\Users\\ongng\\Downloads\\Sample_Detection_Tracking_Yolov8_DeepSORT_Robotics-main\\Sample_Detection_Tracking_Yolov8_DeepSORT_Robotics-main\\deep_sort\\deep_sort\mars-small128.pb",
#     max_cosine_distance=0.2,
#     nn_budget=None
# )
# colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for _ in range(100)]
# for i in range(len(images))[800:]:
#     img_ = cv2.imread(images[i])
#     img = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
#     pil_img = Image.fromarray(img)
    
#     inputs = processor(images=pil_img, text=text_labels, return_tensors="pt").to(device)
#     # inputs = processor(images=pil_img, text=text_labels, return_tensors="pt").to(device)
    
#     with torch.no_grad():
#         outputs = model(**inputs)
    
#     results = processor.post_process_grounded_object_detection(
#         outputs, threshold=threshold, target_sizes=[(pil_img.height, pil_img.width)]
#     )[0]
#     # results = results.numpy()
#     bboxes = [b.cpu().detach().numpy() for b in results['boxes']]
#     scores = [s.cpu().detach().numpy() for s in results['scores']]
#     detections = [list(bboxes[i]) + [scores[i]] for i in range(len(scores))]


#     # for idx,item in enumerate(detections):
#     #     print(item[0])
#     #     print(item[1]) 
#     #DEEP SORT------------------------
#     # print(detections)
#     deepsort.update(img, detections)
#     # print
#     for track in deepsort.tracks:
#         # print(track)
#         x1, y1, x2, y2 = track.bbox
#         track_id = track.track_id
        
#         color = colors[track_id % len(colors)]
#         cv2.rectangle(img_, (int(x1), int(y1)), (int(x2), int(y2)), color, 1)
#         cv2.putText(img_, f"ID: {track_id}", (int(x1), int(y1) - 10),
#                     cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
#     # cv2.imshow(img)
#     out_img_dir = output_dir+"/"+f"{i:04}.jpg"
#     cv2.imwrite(out_img_dir, img_)
#     if i%30 == 0:
#         print(f'Detected {i}/{len(images)} images')
    
#     # print('x')

#     # Write the processed img into the output video
#     # out.write(img)

# # Release resources


# # print(f"Video saved as {output_file}")

# %%
# glob.glob(f"{image_dir}{pattern}*.jpg")
