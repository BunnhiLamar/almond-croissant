# %%
import torch
from transformers import AutoModelForZeroShotObjectDetection, AutoProcessor
from transformers.image_utils import load_image
import torch
import cv2
import numpy as np
import os
import random
from transformers import AutoModelForZeroShotObjectDetection, AutoProcessor
from PIL import Image
# Deep SORT imports
from deep_sort.deep_sort.tracker import Tracker as DeepSortTracker
from deep_sort.tools import generate_detections as gdet
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.detection import Detection

# %%
# Prepare processor and model
model_id = "iSEE-Laboratory/llmdet_tiny"
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)

# Prepare inputs
image_url = "/home/nhinguyen/Desktop/OmniLRS/OmniLRS/scripts/nhi/rover_data_20250804_114916/photo_0038.jpg"
image = load_image(image_url)
text_labels = [["rover"]]
inputs = processor(images=image, text=text_labels, return_tensors="pt").to(device)

# Run inference
with torch.no_grad():
    outputs = model(**inputs)

# Postprocess outputs
results = processor.post_process_grounded_object_detection(
    outputs,
    threshold=0.4,
    target_sizes=[(image.height, image.width)]
)

# Retrieve the first image result
result = results[0]
for box, score, labels in zip(result["boxes"], result["scores"], result["labels"]):
    box = [round(x, 2) for x in box.tolist()]
    print(f"Detected {labels} with confidence {round(score.item(), 3)} at location {box}")
# Out:
# Detected rover with confidence 0.733 at location [249.08, 542.25, 421.49, 648.52]
# Detected rover with confidence 0.732 at location [1042.32, 500.53, 1172.6, 577.09]

# %%
# Load model
model_id = "iSEE-Laboratory/llmdet_tiny"
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)

# Video paths and settings
input_video = "/home/nhinguyen/Downloads/lunar_videos/1.mp4"
output_video = "/home/nhinguyen/Downloads/lunar_videos/1_detect.mp4"
text_labels = [["rover", "robot", "occluded rover", "moving rover"]]
threshold = 0.4

# Process video
cap = cv2.VideoCapture(input_video)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    # Convert and detect
    pil_img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    inputs = processor(images=pil_img, text=text_labels, return_tensors="pt").to(device)
    
    with torch.no_grad():
        outputs = model(**inputs)
    
    results = processor.post_process_grounded_object_detection(
        outputs, threshold=threshold, target_sizes=[(pil_img.height, pil_img.width)]
    )[0]
    
    # Draw boxes
    for box, score, label in zip(results["boxes"], results["scores"], results["labels"]):
        x1, y1, x2, y2 = [int(x) for x in box.tolist()]
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f"{label}: {score:.3f}", (x1, y1-10), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    out.write(frame)

cap.release()
out.release()

# %% [markdown]
# ### __DeepSORT__

# %%
class Track:
    """
    A simple container to hold track_id and bbox data.
    """
    def __init__(self, track_id, bbox):
        self.track_id = track_id
        self.bbox = bbox


class DeepSortWrapper:
    """
    Wrapper class around the Deep SORT functionality.
    """
    def __init__(self, model_filename='model_data/mars-small128.pb', max_cosine_distance=0.4, nn_budget=None):
        metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
        self.tracker = DeepSortTracker(metric)
        self.encoder = gdet.create_box_encoder(model_filename, batch_size=1)
        self.tracks = []

    def update(self, frame, detections):
        """
        Args:
            frame (numpy.ndarray): Current video frame (BGR).
            detections (list): List of detections in [x1, y1, x2, y2, score] format.
        """

        # Step 1: If no detections, just run tracker predict
        if len(detections) == 0:
            self.tracker.predict()
            self.tracker.update([])
            self._update_tracks()
            return

        # Step 2: Convert [x1, y1, x2, y2] to [x, y, w, h]
        bboxes = np.array([d[:4] for d in detections])
        scores = [d[4] for d in detections]

        bboxes[:, 2:] = bboxes[:, 2:] - bboxes[:, :2]  # width, height

        # Step 3: Generate features for each bbox
        features = self.encoder(frame, bboxes)

        # Step 4: Wrap Deep SORT detections
        dets = []
        for bbox_id, bbox in enumerate(bboxes):
            dets.append(Detection(bbox, scores[bbox_id], features[bbox_id]))

        # Step 5: Run the tracker
        self.tracker.predict()
        self.tracker.update(dets)
        self._update_tracks()

    def _update_tracks(self):
        """
        Refresh self.tracks with updated tracks from the deep_sort tracker
        """
        active_tracks = []
        for track in self.tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()  # returns [x1, y1, x2, y2]
            track_id = track.track_id
            active_tracks.append(Track(track_id, bbox))

        self.tracks = active_tracks

# %% [markdown]
# ### __LLMDet + DeepSort__

# %%
# Load model
model_id = "iSEE-Laboratory/llmdet_tiny"
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForZeroShotObjectDetection.from_pretrained(model_id).to(device)

# Video paths and settings
input_video = "/home/nhinguyen/Downloads/lunar_videos/1.mp4"
output_video = "/home/nhinguyen/Downloads/lunar_videos/1_detect_tracking.mp4"
text_labels = [["rover"]]
threshold = 0.4

# output_dir = "/results/"

# Process video
cap = cv2.VideoCapture(input_video)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# %%
from natsort import natsorted
import glob
image_dir = f"C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504/"
output_dir=os.path.join(f"C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/", image_dir.split('/')[-2]+'/')
pattern = "photo"
images = natsorted(glob.glob(f"{image_dir}{pattern}*.jpg"))
# images
os.makedirs(output_dir,exist_ok=True)
print(output_dir)
# Out:
# C:/Users/ongng/OneDrive/Desktop/SEA-RAFT/nhi_results_draft/rover_data_20250804_112504/

# %%
deepsort = DeepSortWrapper(
    model_filename="C:\\Users\\ongng\\Downloads\\Sample_Detection_Tracking_Yolov8_DeepSORT_Robotics-main\\Sample_Detection_Tracking_Yolov8_DeepSORT_Robotics-main\\deep_sort\\deep_sort\mars-small128.pb",
    max_cosine_distance=0.2,
    nn_budget=None
)
colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for _ in range(100)]
for i in range(len(images))[800:]:
    img_ = cv2.imread(images[i])
    img = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(img)
    inputs = processor(images=pil_img, text=text_labels, return_tensors="pt").to(device)
    # inputs = processor(images=pil_img, text=text_labels, return_tensors="pt").to(device)
    
    with torch.no_grad():
        outputs = model(**inputs)
    
    results = processor.post_process_grounded_object_detection(
        outputs, threshold=threshold, target_sizes=[(pil_img.height, pil_img.width)]
    )[0]
    # results = results.numpy()
    bboxes = [b.cpu().detach().numpy() for b in results['boxes']]
    scores = [s.cpu().detach().numpy() for s in results['scores']]
    detections = [list(bboxes[i]) + [scores[i]] for i in range(len(scores))]

    # for idx,item in enumerate(detections):
    #     print(item[0])
    #     print(item[1]) 
    #DEEP SORT------------------------
    # print(detections)
    deepsort.update(img, detections)
    # print
    for track in deepsort.tracks:
        # print(track)
        x1, y1, x2, y2 = track.bbox
        track_id = track.track_id
        
        color = colors[track_id % len(colors)]
        cv2.rectangle(img_, (int(x1), int(y1)), (int(x2), int(y2)), color, 1)
        cv2.putText(img_, f"ID: {track_id}", (int(x1), int(y1) - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
    # cv2.imshow(img)
    out_img_dir = output_dir+"/"+f"{i:04}.jpg"
    cv2.imwrite(out_img_dir, img_)
    if i%30 == 0:
        print(f'Detected {i}/{len(images)} images')
    
    # print('x')

    # Write the processed img into the output video
    # out.write(img)

# Release resources


# print(f"Video saved as {output_file}")
# Out:
# Detected 810/1177 images
# Detected 840/1177 images
# Detected 870/1177 images
# Detected 900/1177 images
# Detected 930/1177 images
# Detected 960/1177 images
# Detected 990/1177 images
# Detected 1020/1177 images
# Detected 1050/1177 images
# Detected 1080/1177 images
# Detected 1110/1177 images
# Detected 1140/1177 images
# Detected 1170/1177 images

# %%
# glob.glob(f"{image_dir}{pattern}*.jpg")
# Out:
# ['C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0000.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0001.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0002.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0003.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0004.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0005.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0006.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0007.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0008.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0009.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0010.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0011.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0012.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0013.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0014.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0015.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0016.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0017.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0018.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0019.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0020.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0021.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0022.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0023.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0024.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0025.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0026.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0027.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0028.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0029.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0030.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0031.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0032.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0033.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0034.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0035.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0036.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0037.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0038.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0039.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0040.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0041.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0042.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0043.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0044.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0045.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0046.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0047.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0048.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0049.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0050.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0051.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0052.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0053.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0054.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0055.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0056.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0057.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0058.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0059.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0060.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0061.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0062.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0063.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0064.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0065.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0066.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0067.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0068.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0069.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0070.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0071.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0072.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0073.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0074.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0075.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0076.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0077.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0078.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0079.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0080.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0081.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0082.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0083.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0084.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0085.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0086.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0087.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0088.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0089.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0090.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0091.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0092.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0093.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0094.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0095.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0096.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0097.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0098.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0099.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0100.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0101.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0102.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0103.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0104.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0105.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0106.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0107.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0108.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0109.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0110.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0111.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0112.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0113.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0114.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0115.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0116.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0117.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0118.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0119.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0120.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0121.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0122.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0123.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0124.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0125.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0126.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0127.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0128.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0129.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0130.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0131.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0132.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0133.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0134.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0135.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0136.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0137.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0138.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0139.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0140.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0141.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0142.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0143.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0144.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0145.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0146.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0147.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0148.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0149.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0150.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0151.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0152.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0153.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0154.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0155.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0156.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0157.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0158.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0159.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0160.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0161.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0162.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0163.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0164.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0165.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0166.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0167.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0168.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0169.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0170.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0171.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0172.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0173.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0174.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0175.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0176.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0177.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0178.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0179.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0180.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0181.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0182.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0183.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0184.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0185.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0186.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0187.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0188.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0189.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0190.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0191.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0192.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0193.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0194.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0195.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0196.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0197.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0198.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0199.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0200.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0201.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0202.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0203.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0204.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0205.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0206.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0207.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0208.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0209.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0210.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0211.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0212.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0213.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0214.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0215.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0216.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0217.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0218.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0219.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0220.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0221.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0222.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0223.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0224.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0225.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0226.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0227.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0228.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0229.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0230.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0231.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0232.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0233.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0234.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0235.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0236.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0237.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0238.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0239.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0240.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0241.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0242.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0243.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0244.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0245.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0246.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0247.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0248.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0249.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0250.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0251.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0252.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0253.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0254.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0255.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0256.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0257.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0258.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0259.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0260.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0261.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0262.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0263.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0264.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0265.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0266.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0267.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0268.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0269.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0270.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0271.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0272.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0273.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0274.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0275.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0276.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0277.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0278.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0279.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0280.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0281.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0282.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0283.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0284.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0285.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0286.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0287.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0288.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0289.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0290.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0291.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0292.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0293.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0294.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0295.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0296.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0297.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0298.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0299.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0300.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0301.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0302.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0303.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0304.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0305.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0306.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0307.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0308.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0309.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0310.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0311.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0312.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0313.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0314.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0315.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0316.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0317.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0318.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0319.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0320.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0321.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0322.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0323.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0324.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0325.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0326.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0327.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0328.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0329.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0330.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0331.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0332.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0333.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0334.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0335.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0336.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0337.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0338.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0339.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0340.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0341.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0342.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0343.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0344.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0345.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0346.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0347.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0348.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0349.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0350.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0351.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0352.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0353.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0354.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0355.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0356.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0357.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0358.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0359.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0360.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0361.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0362.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0363.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0364.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0365.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0366.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0367.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0368.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0369.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0370.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0371.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0372.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0373.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0374.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0375.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0376.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0377.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0378.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0379.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0380.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0381.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0382.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0383.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0384.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0385.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0386.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0387.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0388.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0389.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0390.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0391.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0392.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0393.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0394.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0395.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0396.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0397.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0398.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0399.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0400.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0401.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0402.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0403.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0404.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0405.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0406.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0407.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0408.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0409.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0410.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0411.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0412.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0413.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0414.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0415.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0416.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0417.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0418.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0419.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0420.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0421.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0422.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0423.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0424.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0425.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0426.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0427.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0428.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0429.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0430.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0431.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0432.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0433.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0434.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0435.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0436.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0437.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0438.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0439.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0440.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0441.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0442.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0443.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0444.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0445.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0446.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0447.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0448.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0449.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0450.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0451.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0452.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0453.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0454.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0455.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0456.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0457.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0458.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0459.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0460.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0461.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0462.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0463.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0464.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0465.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0466.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0467.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0468.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0469.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0470.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0471.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0472.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0473.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0474.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0475.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0476.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0477.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0478.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0479.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0480.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0481.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0482.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0483.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0484.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0485.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0486.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0487.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0488.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0489.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0490.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0491.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0492.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0493.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0494.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0495.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0496.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0497.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0498.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0499.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0500.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0501.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0502.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0503.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0504.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0505.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0506.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0507.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0508.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0509.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0510.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0511.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0512.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0513.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0514.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0515.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0516.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0517.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0518.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0519.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0520.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0521.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0522.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0523.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0524.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0525.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0526.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0527.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0528.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0529.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0530.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0531.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0532.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0533.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0534.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0535.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0536.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0537.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0538.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0539.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0540.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0541.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0542.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0543.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0544.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0545.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0546.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0547.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0548.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0549.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0550.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0551.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0552.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0553.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0554.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0555.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0556.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0557.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0558.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0559.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0560.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0561.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0562.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0563.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0564.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0565.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0566.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0567.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0568.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0569.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0570.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0571.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0572.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0573.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0574.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0575.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0576.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0577.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0578.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0579.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0580.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0581.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0582.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0583.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0584.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0585.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0586.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0587.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0588.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0589.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0590.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0591.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0592.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0593.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0594.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0595.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0596.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0597.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0598.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0599.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0600.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0601.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0602.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0603.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0604.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0605.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0606.jpg',
# ...
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0798.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0799.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0800.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0801.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0802.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0803.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0804.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0805.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0806.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0807.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0808.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0809.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0810.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0811.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0812.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0813.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0814.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0815.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0816.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0817.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0818.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0819.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0820.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0821.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0822.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0823.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0824.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0825.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0826.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0827.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0828.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0829.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0830.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0831.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0832.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0833.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0834.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0835.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0836.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0837.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0838.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0839.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0840.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0841.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0842.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0843.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0844.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0845.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0846.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0847.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0848.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0849.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0850.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0851.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0852.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0853.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0854.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0855.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0856.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0857.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0858.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0859.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0860.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0861.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0862.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0863.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0864.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0865.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0866.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0867.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0868.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0869.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0870.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0871.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0872.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0873.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0874.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0875.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0876.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0877.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0878.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0879.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0880.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0881.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0882.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0883.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0884.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0885.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0886.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0887.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0888.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0889.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0890.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0891.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0892.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0893.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0894.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0895.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0896.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0897.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0898.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0899.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0900.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0901.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0902.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0903.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0904.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0905.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0906.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0907.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0908.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0909.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0910.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0911.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0912.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0913.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0914.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0915.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0916.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0917.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0918.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0919.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0920.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0921.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0922.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0923.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0924.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0925.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0926.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0927.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0928.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0929.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0930.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0931.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0932.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0933.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0934.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0935.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0936.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0937.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0938.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0939.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0940.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0941.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0942.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0943.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0944.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0945.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0946.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0947.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0948.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0949.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0950.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0951.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0952.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0953.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0954.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0955.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0956.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0957.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0958.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0959.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0960.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0961.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0962.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0963.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0964.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0965.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0966.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0967.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0968.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0969.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0970.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0971.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0972.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0973.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0974.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0975.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0976.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0977.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0978.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0979.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0980.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0981.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0982.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0983.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0984.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0985.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0986.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0987.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0988.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0989.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0990.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0991.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0992.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0993.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0994.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0995.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0996.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0997.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0998.jpg',
#  'C:/Users/ongng/OneDrive/Desktop/rover_data_20250804_112504\\photo_0999.jpg',
#  ...]
